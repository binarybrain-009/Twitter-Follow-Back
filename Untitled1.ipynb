# %%
from __future__ import print_function
import pandas as pd
import numpy as np


import matplotlib.pyplot as plt
# %matplotlib inline
import sys

# %%
train = pd.read_csv(r'twitter user data2.csv', encoding='ISO-8859-1')
print(train)
# Out:
#         _unit_id  _golden _last_judgment_at   gender profile_yn  \
# 0      815719226    False  10/26/2015 23:24     male        yes
# 1      815719227    False  10/26/2015 23:30     male        yes
# 2      815719228    False  10/26/2015 23:33     male        yes
# 3      815719229    False  10/26/2015 23:10     male        yes
# 4      815719230    False   10/27/2015 1:15   female        yes
# 5      815719231    False   10/27/2015 1:47   female        yes
# 6      815719232    False   10/27/2015 1:57    brand        yes
# 7      815719233    False  10/26/2015 23:48     male        yes
# 8      815719234    False   10/27/2015 1:52   female        yes
# 9      815719235    False   10/27/2015 1:49   female        yes
# 10     815719236    False  10/26/2015 23:17    brand        yes
# 11     815719237    False  10/26/2015 22:33    brand        yes
# 12     815719238    False  10/26/2015 22:20   female        yes
# 13     815719239    False  10/26/2015 23:29    brand        yes
# ...

# %%
train.describe()
# Out:
#            _unit_id  profile_yn:confidence     fav_number  retweet_count  \
# count  2.005000e+04           20050.000000   20050.000000   20050.000000
# mean   8.157294e+08               0.993221    4382.201646       0.079401
# std    6.000801e+03               0.047168   12518.575919       2.649751
# min    8.157192e+08               0.627200       0.000000       0.000000
# 25%    8.157243e+08               1.000000      11.000000       0.000000
# 50%    8.157294e+08               1.000000     456.000000       0.000000
# 75%    8.157345e+08               1.000000    3315.500000       0.000000
# max    8.157580e+08               1.000000  341621.000000     330.000000
#
#         tweet_count      tweet_id
# count  2.005000e+04  2.005000e+04
# mean   3.892469e+04  6.590000e+17
# std    1.168371e+05  1.536038e+05
# min    1.000000e+00  6.590000e+17
# 25%    2.398000e+03  6.590000e+17
# 50%    1.144150e+04  6.590000e+17
# 75%    4.002750e+04  6.590000e+17
# ...

# %%
train.head()
# Out:
#     _unit_id  _golden _last_judgment_at  gender profile_yn  \
# 0  815719226    False  10/26/2015 23:24    male        yes
# 1  815719227    False  10/26/2015 23:30    male        yes
# 2  815719228    False  10/26/2015 23:33    male        yes
# 3  815719229    False  10/26/2015 23:10    male        yes
# 4  815719230    False   10/27/2015 1:15  female        yes
#
#    profile_yn:confidence           created  \
# 0                    1.0    12/5/2013 1:48
# 1                    1.0   10/1/2012 13:51
# 2                    1.0  11/28/2014 11:30
# 3                    1.0   6/11/2009 22:39
# 4                    1.0   4/16/2014 13:23
#
#                                          description  fav_number gender_gold  \
# 0                              i sing my own rhythm.           0         NaN
# 1  I'm the author of novels filled with family dr...          68         NaN
# 2                louis whining and squealing and all        7696         NaN
# ...

# %%
train.shape
# Out:
# (20050, 20)

# %%
train.drop(["_last_judgment_at", "description", "name","text", "profile_yn_gold", "tweet_created", "user_timezone, "tweet_location"], axis=1, inplace=True)
# Out:
#   File "<ipython-input-75-8214df4397a5>", line 1
#     train.drop(["_last_judgment_at", "description", "name","text", "profile_yn_gold", "tweet_created", "user_timezone, "tweet_location"], axis=1, inplace=True)
#                                                                                                                                      ^
# SyntaxError: invalid syntax

# %% [raw]
# train.head()

# %%
train.drop(columns="tweet_location")train.drop(columns="tweet_location")
# Out:
#         _unit_id  _golden   gender  fav_number  retweet_count  tweet_count  \
# 0      815719226    False     male           0              0       110964
# 1      815719227    False     male          68              0         7471
# 2      815719228    False     male        7696              1         5617
# 3      815719229    False     male         202              0         1693
# 4      815719230    False   female       37318              0        31462
# 5      815719231    False   female        3901              0        20036
# 6      815719232    False    brand        4122              0        13354
# 7      815719233    False     male          80              0       112117
# 8      815719234    False   female        1825              0          482
# 9      815719235    False   female        3115              0        26085
# 10     815719236    False    brand         516              0         5179
# ...

# %%
train.head()
# Out:
#     _unit_id  _golden  gender  fav_number  retweet_count  tweet_count  \
# 0  815719226    False    male           0              0       110964
# 1  815719227    False    male          68              0         7471
# 2  815719228    False    male        7696              1         5617
# 3  815719229    False    male         202              0         1693
# 4  815719230    False  female       37318              0        31462
#
#     tweet_location               user_timezone
# 0  main; @Kan1shk3                     Chennai
# 1              NaN  Eastern Time (US & Canada)
# 2           clcncl                    Belgrade
# 3    Palo Alto, CA  Pacific Time (US & Canada)
# 4              NaN                         NaN

# %%
train.drop(columns="tweet_location")
# Out:
#         _unit_id  _golden   gender  fav_number  retweet_count  tweet_count  \
# 0      815719226    False     male           0              0       110964
# 1      815719227    False     male          68              0         7471
# 2      815719228    False     male        7696              1         5617
# 3      815719229    False     male         202              0         1693
# 4      815719230    False   female       37318              0        31462
# 5      815719231    False   female        3901              0        20036
# 6      815719232    False    brand        4122              0        13354
# 7      815719233    False     male          80              0       112117
# 8      815719234    False   female        1825              0          482
# 9      815719235    False   female        3115              0        26085
# 10     815719236    False    brand         516              0         5179
# ...

# %%
train.head()
# Out:
#     _unit_id  _golden  gender  fav_number  retweet_count  tweet_count  \
# 0  815719226    False    male           0              0       110964
# 1  815719227    False    male          68              0         7471
# 2  815719228    False    male        7696              1         5617
# 3  815719229    False    male         202              0         1693
# 4  815719230    False  female       37318              0        31462
#
#     tweet_location               user_timezone
# 0  main; @Kan1shk3                     Chennai
# 1              NaN  Eastern Time (US & Canada)
# 2           clcncl                    Belgrade
# 3    Palo Alto, CA  Pacific Time (US & Canada)
# 4              NaN                         NaN

# %%
train.head()
# Out:
#     _unit_id  _golden  gender  fav_number  retweet_count  tweet_count  \
# 0  815719226    False    male           0              0       110964
# 1  815719227    False    male          68              0         7471
# 2  815719228    False    male        7696              1         5617
# 3  815719229    False    male         202              0         1693
# 4  815719230    False  female       37318              0        31462
#
#     tweet_location               user_timezone
# 0  main; @Kan1shk3                     Chennai
# 1              NaN  Eastern Time (US & Canada)
# 2           clcncl                    Belgrade
# 3    Palo Alto, CA  Pacific Time (US & Canada)
# 4              NaN                         NaN

# %%
train.drop([ "tweet_location", "user_timezone"], axis=1, inplace=True)

# %%
train.head()
# Out:
#     _unit_id  _golden  gender  fav_number  retweet_count  tweet_count
# 0  815719226    False    male           0              0       110964
# 1  815719227    False    male          68              0         7471
# 2  815719228    False    male        7696              1         5617
# 3  815719229    False    male         202              0         1693
# 4  815719230    False  female       37318              0        31462

# %%
pd.DataFrame.hist(train, figsize = [15,15]);
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python37\site-packages\numpy\lib\histograms.py in _unsigned_subtract(a, b)
#     341     try:
# --> 342         dt = signed_to_unsigned[dt.type]
#     343     except KeyError:
#
# KeyError: <class 'numpy.bool_'>
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-88-548d15bf560e> in <module>
# ----> 1 pd.DataFrame.hist(train, figsize = [15,15]);
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\plotting\_core.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, **kwds)
#    2408     for i, col in enumerate(com.try_sort(data.columns)):
#    2409         ax = _axes[i]
# ...

# %%
train['male'] = train['gender'].map( {'male':1, 'female':0} )
train[['gender', 'male']]
# Out:
#         gender  male
# 0         male   1.0
# 1         male   1.0
# 2         male   1.0
# 3         male   1.0
# 4       female   0.0
# 5       female   0.0
# 6        brand   NaN
# 7         male   1.0
# 8       female   0.0
# 9       female   0.0
# 10       brand   NaN
# 11       brand   NaN
# 12      female   0.0
# 13       brand   NaN
# 14      female   0.0
# 15      female   0.0
# 16      female   0.0
# 17        male   1.0
# 18        male   1.0
# 19     unknown   NaN
# 20      female   0.0
# 21      female   0.0
# 22      female   0.0
# 23        male   1.0
# 24        male   1.0
# 25      female   0.0
# 26       brand   NaN
# 27       brand   NaN
# 28      female   0.0
# 29        male   1.0
# ...        ...   ...
# 20020    brand   NaN
# 20021     male   1.0
# 20022     male   1.0
# 20023     male   1.0
# 20024    brand   NaN
# 20025    brand   NaN
# 20026     male   1.0
# 20027     male   1.0
# 20028   female   0.0
# 20029    brand   NaN
# 20030    brand   NaN
# ...

# %%
train.head()
# Out:
#     _unit_id  _golden  gender  fav_number  retweet_count  tweet_count  Male  \
# 0  815719226    False    male           0              0       110964   1.0
# 1  815719227    False    male          68              0         7471   1.0
# 2  815719228    False    male        7696              1         5617   1.0
# 3  815719229    False    male         202              0         1693   1.0
# 4  815719230    False  female       37318              0        31462   0.0
#
#    male
# 0   1.0
# 1   1.0
# 2   1.0
# 3   1.0
# 4   0.0

# %%
train.tail()
# Out:
#         _unit_id  _golden  fav_number  retweet_count  tweet_count  gender
# 20045  815757572        1         302              0          783       0
# 20046  815757681        1        2513              0        13523       0
# 20047  815757830        1          50              0        26419       0
# 20048  815757921        1       70804              0        56073       0
# 20049  815757985        1        3348              0         2922       0

# %%
train.drop(["Male"], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-126-a0a63a9abc96> in <module>
# ----> 1 train.drop(["Male"], axis=1, inplace=True)
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# ...

# %%
train.head()
# Out:
#     _unit_id  _golden  fav_number  retweet_count  tweet_count  gender
# 0  815719226        0           0              0       110964       0
# 1  815719227        0          68              0         7471       0
# 2  815719228        0        7696              1         5617       0
# 3  815719229        0         202              0         1693       0
# 4  815719230        0       37318              0        31462       0

# %%
train.rename(columns={'male': 'gender'}, inplace=True)

# %%
train.head()
# Out:
#     _unit_id  _golden  fav_number  retweet_count  tweet_count  gender
# 0  815719226        0           0              0       110964       0
# 1  815719227        0          68              0         7471       0
# 2  815719228        0        7696              1         5617       0
# 3  815719229        0         202              0         1693       0
# 4  815719230        0       37318              0        31462       0

# %% [raw]
# train['True'] = train['_golden'].map( {'True':1, 'Female':0} )
# train[['_golden', 'True']]

# %%
train.head()
# Out:
#     _unit_id  _golden  fav_number  retweet_count  tweet_count  gender
# 0  815719226    False           0              0       110964     1.0
# 1  815719227    False          68              0         7471     1.0
# 2  815719228    False        7696              1         5617     1.0
# 3  815719229    False         202              0         1693     1.0
# 4  815719230    False       37318              0        31462     0.0

# %%
train = train.applymap(lambda x: 1 if x == True else x).train.applymap(lambda x: 0 if x=='False' else x)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-104-a92d959e7211> in <module>
# ----> 1 train = train.applymap(lambda x: 1 if x == True else x).train.applymap(lambda x: 0 if x=='False' else x)
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'train'

# %%
train.replace(False, 0, inplace=True)
train.replace(True, 1, inplace=True)

# %%
train.head()
# Out:
#     _unit_id  _golden  fav_number  retweet_count  tweet_count  gender
# 0  815719226    False           0              0       110964     1.0
# 1  815719227    False          68              0         7471     1.0
# 2  815719228    False        7696              1         5617     1.0
# 3  815719229    False         202              0         1693     1.0
# 4  815719230    False       37318              0        31462     0.0

# %%
train._golden = train._golden.astype(int)

# %%
train
# Out:
#         _unit_id  _golden  fav_number  retweet_count  tweet_count  gender
# 0      815719226        0           0              0       110964       0
# 1      815719227        0          68              0         7471       0
# 2      815719228        0        7696              1         5617       0
# 3      815719229        0         202              0         1693       0
# 4      815719230        0       37318              0        31462       0
# 5      815719231        0        3901              0        20036       0
# 6      815719232        0        4122              0        13354       0
# 7      815719233        0          80              0       112117       0
# 8      815719234        0        1825              0          482       0
# 9      815719235        0        3115              0        26085       0
# 10     815719236        0         516              0         5179       0
# 11     815719237        0           0              0        66684       0
# ...

# %%
train.isnull().sum()
# Out:
# _unit_id         0
# _golden          0
# fav_number       0
# retweet_count    0
# tweet_count      0
# gender           0
# dtype: int64

# %%
train.gender[train.gender == 'NaN']   = 0.5
# Out:
# C:\Users\cghdhv\AppData\Roaming\Python\Python37\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# C:\Users\cghdhv\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
train['gender'] = train['gender'].replace(np.nan, 0)

# %%
df['column'] = df['column'].fillna(value)
# Out:
#         _unit_id  _golden  fav_number  retweet_count  tweet_count  gender
# 0      815719226        0           0              0       110964       0
# 1      815719227        0          68              0         7471       0
# 2      815719228        0        7696              1         5617       0
# 3      815719229        0         202              0         1693       0
# 4      815719230        0       37318              0        31462       0
# 5      815719231        0        3901              0        20036       0
# 6      815719232        0        4122              0        13354       0
# 7      815719233        0          80              0       112117       0
# 8      815719234        0        1825              0          482       0
# 9      815719235        0        3115              0        26085       0
# 10     815719236        0         516              0         5179       0
# 11     815719237        0           0              0        66684       0
# ...
